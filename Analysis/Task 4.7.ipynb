# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# Question 1: complete the instructions in the Exercise for creating the “price_label” and “busiest_day” columns

# %%
my_path = r'C:\Users\nkasb\Documents\Instacart Basket Analysis'

# %%
df_orders_products_merged = pd.read_pickle(os.path.join(my_path, '2. Data','Prepared Data', 'orders_products_merged.pkl'))

# %%
df_orders_products_merged.shape
# Out:
# (32642461, 17)

# %%
df_orders_products_merged.describe()
# Out:
#        Unnamed: 0_x    product_id      aisle_id  department_id        prices  \
# count  3.243422e+07  3.243625e+07  3.243422e+07   3.243422e+07  3.243422e+07
# mean   2.557949e+04  2.557664e+04  7.121649e+01   9.922233e+00  1.198114e+01
# std    1.409769e+04  1.409646e+04  3.820429e+01   6.281190e+00  4.954310e+02
# min    0.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00  1.000000e+00
# 25%    1.353500e+04  1.353500e+04  3.100000e+01   4.000000e+00  4.200000e+00
# 50%    2.525700e+04  2.525600e+04  8.300000e+01   9.000000e+00  7.400000e+00
# 75%    3.793900e+04  3.793500e+04  1.070000e+02   1.600000e+01  1.130000e+01
# max    4.969200e+04  4.968800e+04  1.340000e+02   2.100000e+01  9.999900e+04
#
#        Unnamed: 0_y      order_id       user_id  order_number     order_dow  \
# count  3.264245e+07  3.264245e+07  3.264245e+07  3.264245e+07  3.264245e+07
# mean   1.709873e+06  1.710718e+06  1.029381e+05  1.713839e+01  2.739032e+00
# ...

# %%
df = df_orders_products_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 17)

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price range'] = df.apply(price_label, axis = 1)
# Out:
# C:\Users\nkasb\AppData\Local\Temp\ipykernel_25200\3356242099.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price range'] = df.apply(price_label, axis = 1)

# %%
df['price range'].value_counts(dropna = False)
# Out:
# Mid-range product    659373
# Low-range product    331283
# High range             9344
# Name: price range, dtype: int64

# %%
result = []

for value in df_orders_products_merged["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
df_orders_products_merged['busiest day']= result

# %%
df_orders_products_merged['busiest day'].value_counts(dropna= False)
# Out:
# Regularly busy    22576757
# Busiest day        6253163
# Least busy         3812541
# Name: busiest day, dtype: int64

# %% [markdown]
# Question 2: Create new columns as 'Busiest days'

# %%
df_orders_products_merged['order_dow'].value_counts(dropna= False)
# Out:
# 0.0    6253163
# 1.0    5696950
# 6.0    4530449
# 2.0    4243329
# 5.0    4237104
# 3.0    3868914
# 4.0    3812541
# NaN         11
# Name: order_dow, dtype: int64

# %%
result = []

for value in df_orders_products_merged["order_dow"]:
  if value == 0 or value == 1:
    result.append("Busiest days")
  elif value == 4 or value == 5:
    result.append("Least busy days")
  else:
    result.append("Regularly busy days")

# %% [markdown]
# Question 3: Check the values of this new column for accuracy

# %%
df_orders_products_merged['busiest days']= result

# %%
df_orders_products_merged['busiest days'].value_counts(dropna= False)
# Out:
# Regularly busy days    12642703
# Busiest days           11950113
# Least busy days         8049645
# Name: busiest days, dtype: int64

# %% [markdown]
# there is less regularly busy days but more busiest days and least busy days

# %% [markdown]
# Question 4: Create a new column containing labels called “busiest_period_of_day

# %%
df_orders_products_merged['order_hour_of_day'].value_counts(dropna= False)
# Out:
# 10.0    2781111
# 11.0    2755471
# 14.0    2709199
# 15.0    2682192
# 13.0    2680274
# 12.0    2637614
# 16.0    2554221
# 9.0     2471137
# 17.0    2104292
# 8.0     1729935
# 18.0    1649934
# 19.0    1268412
# 20.0     983258
# 7.0      897191
# 21.0     801073
# 22.0     638693
# 23.0     405070
# 6.0      292540
# 0.0      220354
# 1.0      116595
# 5.0       88664
# 2.0       69906
# 4.0       53639
# 3.0       51675
# NaN          11
# Name: order_hour_of_day, dtype: int64

# %%
result2 = []

for value in df_orders_products_merged["order_hour_of_day"]:
  if value >= 9.0 and value <= 16.0:
    result2.append("Most orders")
  elif value > 16.0 and value <= 23.0 or value >= 7.0 and value <= 9.0:
    result2.append("Average orders")
  else:
    result2.append("Fewest orders")

# %%
result2
# Out:
# ['Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Fewest orders',
#  'Average orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Average orders',
#  'Fewest orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Fewest orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
# ...

# %% [markdown]
# Question 5: Print the frequency for this new column

# %%
df_orders_products_merged['busiest_period_of_days']= result2

# %%
df_orders_products_merged['busiest_period_of_days'].value_counts(dropna= False)
# Out:
# Most orders       21271219
# Average orders    10477858
# Fewest orders       893384
# Name: busiest_period_of_days, dtype: int64

# %% [markdown]
# Question 7: Export data as pickle file

# %%
df_orders_products_merged.to_pickle(os.path.join(my_path, '2. Data','Prepared Data', 'orders_products_merged.pkl'))
