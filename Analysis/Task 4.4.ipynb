# %%
#import librairies
import pandas as pd
import numpy as np
import os

# %%
my_path = r'C:\Users\nkasb\Documents\Instacart Basket Analysis'

# %%
df_ords = pd.read_csv(os.path.join(my_path, '2. Data', 'Original Data', 'orders.csv'),index_col = False)

# %%
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# Question 2: Change an identifier into a non numerical value

# %%
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
df_ords.describe()
# Out:
#            order_id  order_number     order_dow  order_hour_of_day  \
# count  3.421083e+06  3.421083e+06  3.421083e+06       3.421083e+06
# mean   1.710542e+06  1.715486e+01  2.776219e+00       1.345202e+01
# std    9.875817e+05  1.773316e+01  2.046829e+00       4.226088e+00
# min    1.000000e+00  1.000000e+00  0.000000e+00       0.000000e+00
# 25%    8.552715e+05  5.000000e+00  1.000000e+00       1.000000e+01
# 50%    1.710542e+06  1.100000e+01  3.000000e+00       1.300000e+01
# 75%    2.565812e+06  2.300000e+01  5.000000e+00       1.600000e+01
# max    3.421083e+06  1.000000e+02  6.000000e+00       2.300000e+01
#
#        days_since_prior_order
# count            3.214874e+06
# mean             1.111484e+01
# std              9.206737e+00
# min              0.000000e+00
# 25%              4.000000e+00
# 50%              7.000000e+00
# 75%              1.500000e+01
# max              3.000000e+01

# %% [markdown]
# Question 3: change an unintuitiv name without overwriting the data frame

# %%
df_ords_2 = df_ords.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %% [markdown]
# Question 4:what is the busiest hour for placing an order

# %%
df['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# the busiest hour is 10

# %% [markdown]
# Question 5: what is the meaning behind a value of 4 in the "department_id" column

# %%
df_dep = pd.read_csv(os.path.join(my_path, '2. Data', 'Original Data', 'departments.csv'),index_col = False)

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
df_dep_t = df_dep.T

# %%
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
new_header = df_dep_t.iloc[0]

# %%
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %% [markdown]
# Question 6: Create a subset containing only informations about Breakfast

# %%
df_prods = pd.read_csv(os.path.join(my_path, '2. Data', 'Original Data', 'products.csv'),index_col = False)

# %%
df_breakfast = df_prods.loc[df_prods['department_id'].isin([19])]

# %%
df_breakfast.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %% [markdown]
# Question 7: dinner parties

# %%
df_parties = df_prods.loc[df_prods['department_id'].isin([19, 20, 5, 7, 12])]

# %%
df_parties
# Out:
#        product_id                                    product_name  aisle_id  \
# 0               1                      Chocolate Sandwich Cookies        61
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# ...           ...                                             ...       ...
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49683       49679                         Famous Chocolate Wafers        61
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %% [markdown]
# Question:8 How many rows is the dataframe? 13914

# %%
df_parties.shape
# Out:
# (13914, 5)

# %% [markdown]
# Question 9: Extract every information about user_id 1

# %%
df_user =  df_ords[df_ords['user_id']== '1']

# %%
df_user
# Out:
#     order_id user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329       1    prior             1                   2
# 1    2398795       1    prior             2                   3
# 2     473747       1    prior             3                   3
# 3    2254736       1    prior             4                   4
# 4     431534       1    prior             5                   4
# 5    3367565       1    prior             6                   2
# 6     550135       1    prior             7                   1
# 7    3108588       1    prior             8                   1
# 8    2295261       1    prior             9                   1
# 9    2550362       1    prior            10                   4
# 10   1187899       1    train            11                   4
#
#     order_hour_of_day  days_since_prior_order
# 0                   8                     NaN
# 1                   7                    15.0
# 2                  12                    21.0
# ...

# %%
df_user.describe()
# Out:
#            order_id  order_number  orders_day_of_week  order_hour_of_day  \
# count  1.100000e+01     11.000000           11.000000          11.000000
# mean   1.923450e+06      6.000000            2.636364          10.090909
# std    1.071950e+06      3.316625            1.286291           3.477198
# min    4.315340e+05      1.000000            1.000000           7.000000
# 25%    8.690170e+05      3.500000            1.500000           7.500000
# 50%    2.295261e+06      6.000000            3.000000           8.000000
# 75%    2.544846e+06      8.500000            4.000000          13.000000
# max    3.367565e+06     11.000000            4.000000          16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %%
df_ords.to_csv(os.path.join(my_path, '2. Data','Prepared Data', 'orders_wrangled.csv'))

# %%
df_dep_t_new.to_csv(os.path.join(my_path, '2. Data','Prepared Data', 'departments_wrangled.csv'))

# %%
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64
